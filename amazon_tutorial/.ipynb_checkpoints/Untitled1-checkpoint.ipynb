# %%
import scrapy
from scrapy.crawler import CrawlerProcess

import re

class AmazonspiderSpider(scrapy.Spider):
    name = 'amazon'
    
#     start_urls = [
#         'https://www.amazon.eg/s?rh=n%3A21832907031&fs=true&language=en&ref=lp_21832907031_sar'
#     ]
#     page_no = 2

    headers = {
        "DOWNLOADER_MIDDLEWARES" : {
            'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware': None,
            'scrapy_user_agents.middlewares.RandomUserAgentMiddleware': 400,
        }
    }
    
    type_header_name = True
    
    def start_requests( self ):
        url = 'https://www.amazon.eg/s?rh=n%3A21832907031&fs=true&language=en&ref=lp_21832907031_sar'
        yield scrapy.Request( url = url, callback = self.parse , headers=AmazonspiderSpider.headers)

    def parse(self, response):
#         items_dict = {}
        
        #hint: when use googlebot user agent, things go different. It's better to use scrapy-user-agent

        products_data_asin = response.css('::attr(data-asin)').extract()
        while '' in products_data_asin:
            products_data_asin.remove('')
        
        product_title = []
        product_price = []
        product_imageLink = []
        product_hyperLink = []
        for product in products_data_asin:
            product_data_asin_css = response.css('[data-asin='+product+']')
            product_title.append(product_data_asin_css.css('.a-color-base.a-text-normal').css('::text').extract_first())
            try:
                product_price.append(product_data_asin_css.css('.a-price-whole').css('::text').extract_first())
            except:
                product_price.append('no price found')
            product_imageLink.append(product_data_asin_css.css('.rush-component:nth-child(2) .s-image').css('::attr(src)').extract_first())
            product_hyperLink.append(product_data_asin_css.css('.a-link-normal.a-text-normal').css('::attr(href)').extract_first())
        
        items_dict['product_title'] = product_title
        items_dict['product_price'] = product_price
        items_dict['product_imageLink'] = product_imageLink
        items_dict['product_hyperLink'] = product_hyperLink

        print(f'product_title: {len(product_title)}')
        print(f'product_price: {len(product_price)}')
        print(f'product_imageLink: {len(product_imageLink)}')
        print(f'product_hyperLink: {len(product_hyperLink)}')
        
        # csv coded from scratch is tap seperated for better control as titles can have ',' commas
#         fields = ['product_title','product_price','product_imageLink', 'product_hyperLink']
#         with open('output.csv',"a", encoding="utf-8") as f: # handle the source file
#             if AmazonspiderSpider.type_header_name == True:
#                 f.write("{}\n".format('\t'.join(str(field)for field in fields))) # write header 
#                 AmazonspiderSpider.type_header_name = False
                
#             for i in range(len(items_dict['product_title'])):
#                 for item in items_dict:
#                     f.write("{}\t".format(str((items_dict[item])[i]))) # write items
#                 f.write("\n")
        
        # csv using pandas and dict
        
        df = pd.DataFrame.from_dict(items_dict)
        if AmazonspiderSpider.type_header_name == True:
            df.to_csv('output_ipynb.csv', mode='a', index=False)
            AmazonspiderSpider.type_header_name = False
        else:
            df.to_csv('output_ipynb.csv', mode='a', index=False, header=False)
                
        yield items_dict


items_dict = {}
process = CrawlerProcess()
process.crawl(AmazonspiderSpider)
process.start()
# Out:
# 2021-11-23 04:12:05 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-11-23 04:12:05 [scrapy.utils.log] INFO: Versions: lxml 4.6.4.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 3.4.7, Platform Windows-10-10.0.22000-SP0
# 2021-11-23 04:12:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-11-23 04:12:05 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-11-23 04:12:05 [scrapy.extensions.telnet] INFO: Telnet Password: 541559c891b6b9ae
# 2021-11-23 04:12:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-11-23 04:12:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-11-23 04:12:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-11-23 04:12:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-11-23 04:12:05 [scrapy.core.engine] INFO: Spider opened
# 2021-11-23 04:12:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-11-23 04:12:05 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-11-23 04:12:06 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.amazon.eg/Laptops/b?ie=UTF8&node=21832907031> from <GET https://www.amazon.eg/s?rh=n%3A21832907031&fs=true&language=en&ref=lp_21832907031_sar>
# 2021-11-23 04:12:07 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.amazon.eg/%D9%84%D8%A7%D8%A8-%D8%AA%D9%88%D8%A8%D8%A7%D8%AA/b?ie=UTF8&node=21832907031> from <GET https://www.amazon.eg/Laptops/b?ie=UTF8&node=21832907031>
# 2021-11-23 04:12:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.eg/%D9%84%D8%A7%D8%A8-%D8%AA%D9%88%D8%A8%D8%A7%D8%AA/b?ie=UTF8&node=21832907031> (referer: None)
# 2021-11-23 04:12:07 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.amazon.eg/%D9%84%D8%A7%D8%A8-%D8%AA%D9%88%D8%A8%D8%A7%D8%AA/b?ie=UTF8&node=21832907031> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\hazem\anaconda3\lib\site-packages\twisted\internet\defer.py", line 1661, in _inlineCallbacks
#     result = current_context.run(gen.send, result)
# StopIteration: <200 https://www.amazon.eg/%D9%84%D8%A7%D8%A8-%D8%AA%D9%88%D8%A8%D8%A7%D8%AA/b?ie=UTF8&node=21832907031>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\hazem\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 55, in mustbe_deferred
#     result = f(*args, **kw)
#   File "C:\Users\hazem\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 58, in process_spider_input
#     return scrape_func(response, request, spider)
#   File "C:\Users\hazem\anaconda3\lib\site-packages\scrapy\core\scraper.py", line 149, in call_spider
#     warn_on_generator_with_return_value(spider, callback)
#   File "C:\Users\hazem\anaconda3\lib\site-packages\scrapy\utils\misc.py", line 245, in warn_on_generator_with_return_value
#     if is_generator_with_return_value(callable):
#   File "C:\Users\hazem\anaconda3\lib\site-packages\scrapy\utils\misc.py", line 230, in is_generator_with_return_value
#     tree = ast.parse(dedent(inspect.getsource(callable)))
#   File "C:\Users\hazem\anaconda3\lib\ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 1
#     def parse(self, response):
#     ^
# IndentationError: unexpected indent
# 2021-11-23 04:12:07 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-11-23 04:12:07 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 938,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 46420,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 2.162635,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 11, 23, 2, 12, 7, 991173),
#  'log_count/DEBUG': 3,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'spider_exceptions/IndentationError': 1,
#  'start_time': datetime.datetime(2021, 11, 23, 2, 12, 5, 828538)}
# 2021-11-23 04:12:07 [scrapy.core.engine] INFO: Spider closed (finished)
